# %%
from IPython.display import display, Image
display(Image(filename='Total Confirmed.png'))
display(Image(filename='Daily Confirmed.png'))
display(Image(filename='Total Confirmed Per 1M Population.png'))
display(Image(filename='Total Deaths.png'))
display(Image(filename='Daily Deaths.png'))
display(Image(filename='Total Mortality.png'))
display(Image(filename='Total Deaths Per 1M Population.png'))
